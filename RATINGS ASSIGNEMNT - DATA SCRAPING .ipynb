# %% [markdown]
# ## RATINGS ASSIGNEMNT - DATA SCRAPING

# %%
import pandas as pd
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"/Users/natashapoddar/chromedriver")

# %%
url = "https://www.amazon.in/"
driver.get(url)
time.sleep(3)

# %%
srch_items = ['Professional Cameras', 'Printers']
title = []
review_text = []
ratings = []

for i in srch_items:
    srchbar = driver.find_element(By.ID, "twotabsearchtextbox")
    srchbar.send_keys(i)
    driver.find_element(By.ID, "nav-search-submit-button").click()  #clicking on search button
    time.sleep(1)
    item_url = []
    for i in driver.find_elements(By.XPATH, "//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
        item_url.append(i.get_attribute('href')) # gets the url of the item
    for i in item_url:
        driver.get(i)
        time.sleep(1)
        for _ in range(2):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(1)
        try:
            driver.find_element(By.XPATH, "//a[@class='a-link-emphasis a-text-bold']").click()
        except:pass

# %%
url_ = []
try:
    two_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
    url_.append(two_str.get_attribute('href'))
except: pass
try:
    three_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
    url_.append(three_str.get_attribute('href'))
except: pass
try:
    one_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
    url_.append(one_str.get_attribute('href'))
except: pass
try:
    fiv_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
    url_.append(fiv_str.get_attribute('href'))
except: pass
try:
    four_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
    url_.append(four_str.get_attribute('href'))
except: pass

# %%
for i in url_:
    driver.get(i)
    time.sleep(1)
    for i in range(10):
        ids = driver.find_elements(By.XPATH, "//div[@class='a-section a-spacing-none review-views celwidget']/div")
        comment_ids = []
        try:
            for i in ids:
                comment_ids.append(i.get_attribute('id'))
        except StaleElementReferenceException:
            pass
        for x in comment_ids:
            try:
                review_title = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
                title.append(review_title.get_attribute("innerHTML"))
            except NoSuchElementException:
                title.append('')
            except StaleElementReferenceException:
                pass
            try:
                rating = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
                ratings.append(rating.get_attribute("innerHTML"))
            except NoSuchElementException:
                ratings.append('')
            except StaleElementReferenceException:
                pass
            try:
                text = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[4]/span/span')
                review_text.append(text.get_attribute("innerHTML"))
            except NoSuchElementException:
                review_text.append('')
            except StaleElementReferenceException:
                pass
                    
        try:
            driver.find_element(By.XPATH, "//ul[@class='a-pagination']/li[2]/a").click()
            time.sleep(3)
        except : break

# %%
len(ratings),len(title),len(review_text)
# Out:
# (596, 596, 596)

# %%
rat1=pd.DataFrame({'TITLE':title,'REVIEW':review_text,'RATINGS':ratings})

# %%
rat1
# Out:
#                                                  TITLE  \
# 0    HP SMART APP? HP DULL APP! HP TECH Support (IN...
# 1    Printer cost is low but catrege cost is very high
# 2         Cartridge is the one to drill hole in pocket
# 3                      Constant leakage of cartridge.😠
# 4                           I made a mistake buying it
# ..                                                 ...
# 591                                               Good
# 592                            All in one best printer
# 593                      Good product. Value for money
# 594                                          My review
# 595
#
#                                                 REVIEW             RATINGS
# 0    I ordered this machine to copy, print, and sca...  2.0 out of 5 stars
# 1    Printer cost is low but cartridge cost very hi...  2.0 out of 5 stars
# 2    Quality and installation very good and easy. C...  2.0 out of 5 stars
# 3                                                       2.0 out of 5 stars
# 4    I bought it this year in Jan, and I am regrett...  2.0 out of 5 stars
# ..                                                 ...                 ...
# 591                                          Very good  4.0 out of 5 stars
# 592                          Best picture high quality  4.0 out of 5 stars
# 593                                      Great product  4.0 out of 5 stars
# 594  Nice design<br>Excellent print quality<br>It t...  4.0 out of 5 stars
# 595
#
# [596 rows x 3 columns]

# %%
url = "https://www.amazon.in/"
driver.get(url)
time.sleep(3)

# %%
srch_items = ['Smart Phone','speakers']
title = []
review_text = []
ratings = []

for i in srch_items:
    srchbar = driver.find_element(By.ID, "twotabsearchtextbox")
    srchbar.send_keys(i)
    driver.find_element(By.ID, "nav-search-submit-button").click()  #clicking on search button
    time.sleep(1)
    item_url = []
    for i in driver.find_elements(By.XPATH, "//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
        item_url.append(i.get_attribute('href')) # gets the url of the item
    for i in item_url:
        driver.get(i)
        time.sleep(1)
        for _ in range(2):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(1)
        try:
            driver.find_element(By.XPATH, "//a[@class='a-link-emphasis a-text-bold']").click()
        except:pass

# %%
url_ = []
try:
    two_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
    url_.append(two_str.get_attribute('href'))
except: pass
try:
    three_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
    url_.append(three_str.get_attribute('href'))
except: pass
try:
    one_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
    url_.append(one_str.get_attribute('href'))
except: pass
try:
    fiv_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
    url_.append(fiv_str.get_attribute('href'))
except: pass
try:
    four_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
    url_.append(four_str.get_attribute('href'))
except: pass

# %%
for i in url_:
    driver.get(i)
    time.sleep(1)
    for i in range(10):
        ids = driver.find_elements(By.XPATH, "//div[@class='a-section a-spacing-none review-views celwidget']/div")
        comment_ids = []
        try:
            for i in ids:
                comment_ids.append(i.get_attribute('id'))
        except StaleElementReferenceException:
            pass
        for x in comment_ids:
            try:
                review_title = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
                title.append(review_title.get_attribute("innerHTML"))
            except NoSuchElementException:
                title.append('')
            except StaleElementReferenceException:
                pass
            try:
                rating = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
                ratings.append(rating.get_attribute("innerHTML"))
            except NoSuchElementException:
                ratings.append('')
            except StaleElementReferenceException:
                pass
            try:
                text = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[4]/span/span')
                review_text.append(text.get_attribute("innerHTML"))
            except NoSuchElementException:
                review_text.append('')
            except StaleElementReferenceException:
                pass
                    
        try:
            driver.find_element(By.XPATH, "//ul[@class='a-pagination']/li[2]/a").click()
            time.sleep(3)
        except : break

# %%
len(ratings),len(title),len(review_text)
# Out:
# (337, 337, 337)

# %%
rat2=pd.DataFrame({'TITLE':title,'REVIEW':review_text,'RATINGS':ratings})

# %%
rat2
# Out:
#                                                  TITLE  \
# 0
# 1    input cable in the box input cable not found p...
# 2    It shows low battery sign if played at 100% vo...
# 3    Battery back up is very less and not fully cha...
# 4                                          Normal Good
# ..                                                 ...
# 332                           Paisa wasul he bhai best
# 333                            Cost cutting is visible
# 334                                       Good quality
# 335                              Good Battery backup 👌
# 336
#
#                                                 REVIEW             RATINGS
# 0
# 1    Input cable have not been found alongwith the ...  2.0 out of 5 stars
# 2    Bluetooth connectivity is less than 5 meters.<...  2.0 out of 5 stars
# 3    Review after 20 days of purchase. Charged for ...  2.0 out of 5 stars
# 4    His battery is running very bad b that means i...  2.0 out of 5 stars
# ..                                                 ...                 ...
# 332                                               Best  4.0 out of 5 stars
# 333  In short It is good value for money , having c...  4.0 out of 5 stars
# 334  Very good bass. And clear sound. Value for mon...  4.0 out of 5 stars
# 335                                              Best👌  4.0 out of 5 stars
# 336
#
# [337 rows x 3 columns]

# %%
url = "https://www.amazon.in/"
driver.get(url)
time.sleep(3)

# %%
srch_items = ['iphone 13']
title = []
review_text = []
ratings = []

for i in srch_items:
    srchbar = driver.find_element(By.ID, "twotabsearchtextbox")
    srchbar.send_keys(i)
    driver.find_element(By.ID, "nav-search-submit-button").click()  #clicking on search button
    time.sleep(1)
    item_url = []
    for i in driver.find_elements(By.XPATH, "//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
        item_url.append(i.get_attribute('href')) # gets the url of the item
    for i in item_url:
        driver.get(i)
        time.sleep(1)
        for _ in range(2):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(1)
        try:
            driver.find_element(By.XPATH, "//a[@class='a-link-emphasis a-text-bold']").click()
        except:pass

# %%
url_ = []
try:
    two_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
    url_.append(two_str.get_attribute('href'))
except: pass
try:
    three_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
    url_.append(three_str.get_attribute('href'))
except: pass
try:
    one_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
    url_.append(one_str.get_attribute('href'))
except: pass
try:
    fiv_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
    url_.append(fiv_str.get_attribute('href'))
except: pass
try:
    four_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
    url_.append(four_str.get_attribute('href'))
except: pass

# %%
for i in url_:
    driver.get(i)
    time.sleep(1)
    for i in range(10):
        ids = driver.find_elements(By.XPATH, "//div[@class='a-section a-spacing-none review-views celwidget']/div")
        comment_ids = []
        try:
            for i in ids:
                comment_ids.append(i.get_attribute('id'))
        except StaleElementReferenceException:
            pass
        for x in comment_ids:
            try:
                review_title = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
                title.append(review_title.get_attribute("innerHTML"))
            except NoSuchElementException:
                title.append('')
            except StaleElementReferenceException:
                pass
            try:
                rating = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
                ratings.append(rating.get_attribute("innerHTML"))
            except NoSuchElementException:
                ratings.append('')
            except StaleElementReferenceException:
                pass
            try:
                text = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[4]/span/span')
                review_text.append(text.get_attribute("innerHTML"))
            except NoSuchElementException:
                review_text.append('')
            except StaleElementReferenceException:
                pass
                    
        try:
            driver.find_element(By.XPATH, "//ul[@class='a-pagination']/li[2]/a").click()
            time.sleep(3)
        except : break

# %%
len(ratings),len(title),len(review_text)
# Out:
# (331, 331, 331)

# %%
rat3=pd.DataFrame({'TITLE':title,'REVIEW':review_text,'RATINGS':ratings})

# %%
rat3
# Out:
#                                          TITLE  \
# 0                               Not that great
# 1                 Not worth and expected level
# 2                         Cheaper but not best
# 3          Slow charging and heats up my phone
# 4    Charging time - takes longer than claimed
# ..                                         ...
# 326                            Money well used
# 327                                   Good buy
# 328                    Looks awesome and sleek
# 329                                       Good
# 330
#
#                                                 REVIEW             RATINGS
# 0    Very slow charging for s20fe 5g. 4+ hrs to ful...  2.0 out of 5 stars
# 1    This is not worth and it is not charging prope...  2.0 out of 5 stars
# 2    It’s not charging faster as mentioned in descr...  2.0 out of 5 stars
# 3    I really didnt like the product. It is slow to...  2.0 out of 5 stars
# 4            Charging is Not as per the specifications  2.0 out of 5 stars
# ..                                                 ...                 ...
# 326  able to charge my marshal major with this but ...  4.0 out of 5 stars
# 327  Works good for now ! Will update if anything c...  4.0 out of 5 stars
# 328  Awesome charger, looks good and sleek and supp...  4.0 out of 5 stars
# 329  Works in both directions. Both ends are c type...  4.0 out of 5 stars
# 330
#
# [331 rows x 3 columns]

# %%
url ="https://www.amazon.in"
driver.get(url)
time.sleep(3)

# %%
srch_items = ['iphone 12','Samsung Galaxy','iphone 11','one plus']
title = []
review_text = []
ratings = []

for i in srch_items:
    srchbar = driver.find_element(By.ID, "twotabsearchtextbox")
    srchbar.send_keys(i)
    driver.find_element(By.ID, "nav-search-submit-button").click()  #clicking on search button
    time.sleep(1)
    item_url = []
    for i in driver.find_elements(By.XPATH, "//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
        item_url.append(i.get_attribute('href')) # gets the url of the item
    for i in item_url:
        driver.get(i)
        time.sleep(1)
        for _ in range(2):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(1)
        try:
            driver.find_element(By.XPATH, "//a[@class='a-link-emphasis a-text-bold']").click()
        except:pass

# %%
url_ = []
try:
    two_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
    url_.append(two_str.get_attribute('href'))
except: pass
try:
    three_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
    url_.append(three_str.get_attribute('href'))
except: pass
try:
    one_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
    url_.append(one_str.get_attribute('href'))
except: pass
try:
    fiv_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
    url_.append(fiv_str.get_attribute('href'))
except: pass
try:
    four_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
    url_.append(four_str.get_attribute('href'))
except: pass

# %%
for i in url_:
    driver.get(i)
    time.sleep(1)
    for i in range(10):
        ids = driver.find_elements(By.XPATH, "//div[@class='a-section a-spacing-none review-views celwidget']/div")
        comment_ids = []
        try:
            for i in ids:
                comment_ids.append(i.get_attribute('id'))
        except StaleElementReferenceException:
            pass
        for x in comment_ids:
            try:
                review_title = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
                title.append(review_title.get_attribute("innerHTML"))
            except NoSuchElementException:
                title.append('')
            except StaleElementReferenceException:
                pass
            try:
                rating = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
                ratings.append(rating.get_attribute("innerHTML"))
            except NoSuchElementException:
                ratings.append('')
            except StaleElementReferenceException:
                pass
            try:
                text = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[4]/span/span')
                review_text.append(text.get_attribute("innerHTML"))
            except NoSuchElementException:
                review_text.append('')
            except StaleElementReferenceException:
                pass
                    
        try:
            driver.find_element(By.XPATH, "//ul[@class='a-pagination']/li[2]/a").click()
            time.sleep(3)
        except : break

# %%
len(ratings),len(title),len(review_text)
# Out:
# (595, 595, 595)

# %%
rat4=pd.DataFrame({'TITLE':title,'REVIEW':review_text,'RATINGS':ratings})

# %%
rat4
# Out:
#                                                  TITLE  \
# 0                                Issues after 3 months
# 1                                     Poor after sales
# 2                                      Defective model
# 3                  Volume in one ear bud has gone down
# 4    Decent but would wait for the replacement product
# ..                                                 ...
# 590  We have purchased one plus buds pro left ear b...
# 591                                      Awesome sound
# 592                                    Worth the money
# 593                                 Good sound quality
# 594
#
#                                                 REVIEW             RATINGS
# 0    I ought to mention the first thing that impres...  2.0 out of 5 stars
# 1    I have used the buds for over year now. They s...  2.0 out of 5 stars
# 2    There seems to be some defect in this model as...  2.0 out of 5 stars
# 3    The volume in the Right ear bud has reduced su...  2.0 out of 5 stars
# 4    I loved the product initially but then after s...  2.0 out of 5 stars
# ..                                                 ...                 ...
# 590                         I request send my invoice.  4.0 out of 5 stars
# 591  I have giving this review after using it from ...  4.0 out of 5 stars
# 592  It is worth the money if you purchase in a sal...  4.0 out of 5 stars
# 593  I owned OnePlus buds and the sound quality was...  4.0 out of 5 stars
# 594
#
# [595 rows x 3 columns]

# %%
url ="https://www.amazon.in"
driver.get(url)
time.sleep(3)

# %%
srch_items = ['iwatch','alexa','laptop']
title = []
review_text = []
ratings = []

for i in srch_items:
    srchbar = driver.find_element(By.ID, "twotabsearchtextbox")
    srchbar.send_keys(i)
    driver.find_element(By.ID, "nav-search-submit-button").click()  #clicking on search button
    time.sleep(1)
    item_url = []
    for i in driver.find_elements(By.XPATH, "//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
        item_url.append(i.get_attribute('href')) # gets the url of the item
    for i in item_url:
        driver.get(i)
        time.sleep(1)
        for _ in range(2):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(1)
        try:
            driver.find_element(By.XPATH, "//a[@class='a-link-emphasis a-text-bold']").click()
        except:pass

# %%
url_ = []
try:
    two_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
    url_.append(two_str.get_attribute('href'))
except: pass
try:
    three_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
    url_.append(three_str.get_attribute('href'))
except: pass
try:
    one_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
    url_.append(one_str.get_attribute('href'))
except: pass
try:
    fiv_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
    url_.append(fiv_str.get_attribute('href'))
except: pass
try:
    four_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
    url_.append(four_str.get_attribute('href'))
except: pass

# %%
for i in url_:
    driver.get(i)
    time.sleep(1)
    for i in range(10):
        ids = driver.find_elements(By.XPATH, "//div[@class='a-section a-spacing-none review-views celwidget']/div")
        comment_ids = []
        try:
            for i in ids:
                comment_ids.append(i.get_attribute('id'))
        except StaleElementReferenceException:
            pass
        for x in comment_ids:
            try:
                review_title = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
                title.append(review_title.get_attribute("innerHTML"))
            except NoSuchElementException:
                title.append('')
            except StaleElementReferenceException:
                pass
            try:
                rating = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
                ratings.append(rating.get_attribute("innerHTML"))
            except NoSuchElementException:
                ratings.append('')
            except StaleElementReferenceException:
                pass
            try:
                text = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[4]/span/span')
                review_text.append(text.get_attribute("innerHTML"))
            except NoSuchElementException:
                review_text.append('')
            except StaleElementReferenceException:
                pass
                    
        try:
            driver.find_element(By.XPATH, "//ul[@class='a-pagination']/li[2]/a").click()
            time.sleep(3)
        except : break

# %%
len(ratings),len(title),len(review_text)
# Out:
# (33, 33, 33)

# %%
rat5=pd.DataFrame({'TITLE':title,'REVIEW':review_text,'RATINGS':ratings})

# %%
# Out:
#                                                 TITLE  \
# 0
# 1                                             Hp name
# 2                                             Average
# 3                        Performance vice nice laptop
# 4             Not good... so hanging... China product
# 5                   Cursor stopped working in one day
# 6                          Dont buy this cheap laptop
# 7                                  low quality laptop
# 8                          Is not working as aspected
# 9                                       Waste product
# 10                                  Very good product
# 11                          HP brand with Intel .....
# 12                                Everything you want
# 13                                       Nice product
# 14                                               Nice
# 15                                        Awesome buy
# 16  My experience 7 days very smooth fast working ...
# 17       Very good processor , good experience to use
# 18                              working speed is good
# 19                            Value for money product
# 20
# 21
# 22                     Colour in silver grey fabulous
# 23
# 24                             Good product under 40k
# 25                                           Good One
# 26                                               Good
# 27                    Best laptop in this price range
# 28                                    Worth for Money
# 29                                No backlit keyboard
# 30                                              Great
# 31      Totally satisfied for the one week experience
# 32          Good for office works not for high gaming
#
#                                                REVIEW             RATINGS
# 0
# 1                                                Good  3.0 out of 5 stars
# 2   All is good but poor screen quality. Looking l...  3.0 out of 5 stars
# 3                        Performance wise nice laptop  3.0 out of 5 stars
# 4   Not good... hanging too much... I bought one m...  3.0 out of 5 stars
# 5   After using the Hp laptop for just one day, th...  1.0 out of 5 stars
# 6   Don't buy this cheap laptop as facing problems...  1.0 out of 5 stars
# 7   This is very low quality laptop. Didn't expect...  1.0 out of 5 stars
# 8             Is very slow and hanging again to again  1.0 out of 5 stars
# 9   Waste of money mouse aakr kha kr xala jata hai...  1.0 out of 5 stars
# 10                                                     5.0 out of 5 stars
# 11  Great laptop in this price range...<br>...... ...  5.0 out of 5 stars
# 12  Product is good and awesome useful for home an...  5.0 out of 5 stars
# 13                                          Very nice  5.0 out of 5 stars
# 14                                                     5.0 out of 5 stars
# 15                          Awesome n value for money  5.0 out of 5 stars
# 16                 Very good for students under 40000  5.0 out of 5 stars
# 17                                                     5.0 out of 5 stars
# 18                               overall good laptop.  5.0 out of 5 stars
# 19           Awesome product....you can go for it..🤟🏻  5.0 out of 5 stars
# 20
# 21
# 22                                    Awesome product  5.0 out of 5 stars
# 23
# 24  Product is good but Amazon packaging really la...  4.0 out of 5 stars
# 25  Decent good laptop at this price point, can ha...  4.0 out of 5 stars
# 26  Sound quality nice,charge system with internet...  4.0 out of 5 stars
# 27  Laptop is very good, light weight cool design....  4.0 out of 5 stars
# 28  It is good product for professional use and st...  4.0 out of 5 stars
# 29                                No backlit keyboard  4.0 out of 5 stars
# 30                                     Amazing laptop  4.0 out of 5 stars
# 31  &nbsp;Overall satisfied with one week usage. I...  4.0 out of 5 stars
# 32                                  40000/-great deal  4.0 out of 5 stars

# %%
url ="https://www.amazon.in"
driver.get(url)
time.sleep(3)

# %%
srch_items = ['smart watches','Monitors', 'Home theater', 'Router','Microwave']
title = []
review_text = []
ratings = []

for i in srch_items:
    srchbar = driver.find_element(By.ID, "twotabsearchtextbox")
    srchbar.send_keys(i)
    driver.find_element(By.ID, "nav-search-submit-button").click()  #clicking on search button
    time.sleep(1)
    item_url = []
    for i in driver.find_elements(By.XPATH, "//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
        item_url.append(i.get_attribute('href')) # gets the url of the item
    for i in item_url:
        driver.get(i)
        time.sleep(1)
        for _ in range(2):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(1)
        # Clicking on see all reviews
        try:
            driver.find_element(By.XPATH, "//a[@class='a-link-emphasis a-text-bold']").click()
        except:
            pass
        # getting the reviews based on the stars they've received
        url_ = []
        try:
            two_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
            url_.append(two_str.get_attribute('href'))
        except: pass
        try:
            three_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
            url_.append(three_str.get_attribute('href'))
        except: pass
        try:
            one_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
            url_.append(one_str.get_attribute('href'))
        except: pass
        try:
            fiv_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
            url_.append(fiv_str.get_attribute('href'))
        except: pass
        try:
            four_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
            url_.append(four_str.get_attribute('href'))
        except: pass
        
        for i in url_:
            driver.get(i)
            time.sleep(1)
            for i in range(10):
                ids = driver.find_elements(By.XPATH, "//div[@class='a-section a-spacing-none review-views celwidget']/div")
                comment_ids = []
                try:
                    for i in ids:
                        comment_ids.append(i.get_attribute('id'))
                except StaleElementReferenceException:
                    pass

                for x in comment_ids:
                    # Extract user IDs from each user on a page
                    try:
                        review_title = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
                        title.append(review_title.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        title.append('')
                    except StaleElementReferenceException:
                        pass

                    try:
                        rating = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
                        ratings.append(rating.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        ratings.append('')
                    except StaleElementReferenceException:
                        pass

                    try:
                        text = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[4]/span/span')
                        review_text.append(text.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        review_text.append('')
                    except StaleElementReferenceException:
                        pass
                    
                try:
                    driver.find_element(By.XPATH, "//ul[@class='a-pagination']/li[2]/a").click()
                    time.sleep(3)
                except : break

# %%
len(review_text)
# Out:
# 44239

# %%
len(ratings)
# Out:
# 44239

# %%
len(title)
# Out:
# 44239

# %%
rat6=pd.DataFrame({'TITLE':title,'REVIEW':review_text,'RATINGS':ratings})

# %%
rat6
# Out:
#                                         TITLE  \
# 0
# 1                              Not an upgrade
# 2      The watch is not accurate as it claims
# 3
# 4
# ...                                       ...
# 44234                Satisfied, worthy to buy
# 44235                                 Perfect
# 44236                       Your aap are good
# 44237                                  Nice 👍
# 44238
#
#                                                   REVIEW             RATINGS
# 0
# 1      The software is having lot of glitches. Doesn’...  2.0 out of 5 stars
# 2      I brought this watch for better sleep and stre...  2.0 out of 5 stars
# 3
# 4      Blazeから買い替え<br>正直期待外れ　近日対応予定の機能が多すぎる（Versa3・Se...
# ...                                                  ...                 ...
# 44234                               Good value for money  5.0 out of 5 stars
# 44235                                            Perfect  5.0 out of 5 stars
# 44236                           Good product easy to use  5.0 out of 5 stars
# 44237                              I like the product...  5.0 out of 5 stars
# 44238
#
# [44239 rows x 3 columns]

# %%
rat6.isnull().sum()
# Out:
# TITLE      0
# REVIEW     0
# RATINGS    0
# dtype: int64

# %%
srch_items = ['Microwave']
title = []
review_text = []
ratings = []

for i in srch_items:
    srchbar = driver.find_element(By.ID, "twotabsearchtextbox")
    srchbar.send_keys(i)
    driver.find_element(By.ID, "nav-search-submit-button").click()  #clicking on search button
    time.sleep(1)
    item_url = []
    for i in driver.find_elements(By.XPATH, "//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a"):
        item_url.append(i.get_attribute('href')) # gets the url of the item
    for i in item_url:
        driver.get(i)
        time.sleep(1)
        for _ in range(2):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(1)
        # Clicking on see all reviews
        try:
            driver.find_element(By.XPATH, "//a[@class='a-link-emphasis a-text-bold']").click()
        except:
            pass
        # getting the reviews based on the stars they've received
        url_ = []
        try:
            two_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[4]/td[2]/a")
            url_.append(two_str.get_attribute('href'))
        except: pass
        try:
            three_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[3]/td[2]/a")
            url_.append(three_str.get_attribute('href'))
        except: pass
        try:
            one_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[5]/td[2]/a")
            url_.append(one_str.get_attribute('href'))
        except: pass
        try:
            fiv_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[1]/td[2]/a")
            url_.append(fiv_str.get_attribute('href'))
        except: pass
        try:
            four_str = driver.find_element(By.XPATH, "//table[@id='histogramTable']/tbody/tr[2]/td[2]/a")
            url_.append(four_str.get_attribute('href'))
        except: pass
        
        for i in url_:
            driver.get(i)
            time.sleep(1)
            for i in range(10):
                ids = driver.find_elements(By.XPATH, "//div[@class='a-section a-spacing-none review-views celwidget']/div")
                comment_ids = []
                try:
                    for i in ids:
                        comment_ids.append(i.get_attribute('id'))
                except StaleElementReferenceException:
                    pass

                for x in comment_ids:
                    # Extract user IDs from each user on a page
                    try:
                        review_title = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[2]/span[1]')
                        title.append(review_title.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        title.append('')
                    except StaleElementReferenceException:
                        pass

                    try:
                        rating = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[2]/a[1]/i/span[1]')
                        ratings.append(rating.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        ratings.append('')
                    except StaleElementReferenceException:
                        pass

                    try:
                        text = driver.find_element(By.XPATH, '//*[@id="' + x +'"]/div/div/div[4]/span/span')
                        review_text.append(text.get_attribute("innerHTML"))
                    except NoSuchElementException:
                        review_text.append('')
                    except StaleElementReferenceException:
                        pass
                    
                try:
                    driver.find_element(By.XPATH, "//ul[@class='a-pagination']/li[2]/a").click()
                    time.sleep(3)
                except : break

# %%
len(review_text)
# Out:
# 6864

# %%
len(ratings)
# Out:
# 6864

# %%
len(title)
# Out:
# 6864

# %%
rat7=pd.DataFrame({'TITLE':title,'REVIEW':review_text,'RATINGS':ratings})

# %%
rat7
# Out:
#                                                   TITLE  \
# 0                                       Problem in oven
# 1                               Power not switching off
# 2                              Inadequate Quality Check
# 3                   Not the best. Makes a lot of noise.
# 4                                        Product damage
# ...                                                 ...
# 6859                           Top opening doesnot work
# 6860  Bit worried abt d delivery of d startup kit.Se...
# 6861                           Great product. Satisfied
# 6862            It's a good product and value for money
# 6863
#
#                                                  REVIEW             RATINGS
# 0                    Very bad product garbage in a year  2.0 out of 5 stars
# 1     Not switching off after pressing the button or...  2.0 out of 5 stars
# 2     The microwave was received well. However  whil...  2.0 out of 5 stars
# 3     &nbsp;The product is very similar to Samsung's...  2.0 out of 5 stars
# 4                       A damage product was sent to me  2.0 out of 5 stars
# ...                                                 ...                 ...
# 6859  The top opening door is a nuisance.<br>Most of...  4.0 out of 5 stars
# 6860  Product is awesome and I got it for 23400/-.Se...  4.0 out of 5 stars
# 6861  Good product. Sturdy good quality material use...  4.0 out of 5 stars
# 6862                        The touch and feel is great  4.0 out of 5 stars
# 6863
#
# [6864 rows x 3 columns]

# %% [markdown]
# ## FLIPKART

# %%
url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(2)

# %%
srch_items = ['Laptops', 'Phones']
title = []
review_text = []
ratings = []

def scrape():    
#         scrape the text
        for i in driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']"):
            review_text.append(i.text)
#         scrape the title of the review
        for i in driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']"):
            title.append(i.text)
#         scrape the rating of the review
        for i in driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']/../div"):
            ratings.append(i.text)
        return
    
urls=[]
for i in srch_items:
    # Find the search bar
    srchBar = driver.find_element(By.XPATH,"//div[@class='_3OO5Xc']/input")
    srchBar.clear()
    srchBar.send_keys(i)
    # Clicking the search button
    driver.find_element(By.XPATH,"//button[@class='L0Z3Pu']").click()
    time.sleep(3)
    
#     going through the pages present for the searched item
    page = []
    for i in driver.find_elements(By.XPATH,"//nav[@class='yFHi8N']/a"):
        page.append(i.get_attribute('href'))
    for i in page[0:4]:
        driver.get(i)
        time.sleep(3)
        items = driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']")
        for i in items:
            urls.append(i.get_attribute('href'))
print (f"The amount of URLs gathered is: {len(urls)}")            

# going to each url
for i in urls[:100]:
    driver.get(i)
    time.sleep(2)
    for _ in range(2):
        driver.execute_script("window.scrollBy(0,6000)")
        time.sleep(1)
    # Clicking on "all reviews"
    try:
        btn = driver.find_element(By.XPATH,"//div[@class='_2c2kV-']/following::a")
        lnk = btn.get_attribute('href')
        driver.get(lnk)
        time.sleep(1)
    except NoSuchElementException: pass

    scrape()        
    try:
        n_page=driver.find_elements(By.XPATH,"//nav[@class='yFHi8N']/a")
        np=[]
        for i in n_page:
            np.append(i.get_attribute('href'))
        for i in np[0:18]:
            driver.get(i)
            time.sleep(1)
            scrape()
    except: continue        

for i in urls[101:200]:
    driver.get(i)
    time.sleep(2)
    for _ in range(2):
        driver.execute_script("window.scrollBy(0,6000)")
        time.sleep(1)
    # Clicking on all reviews
    try:
        btn=driver.find_element(By.XPATH,"//div[@class='_2c2kV-']/following::a")
        lnk = btn.get_attribute('href')
        driver.get(lnk)
        time.sleep(1)
    except NoSuchElementException:
        pass

    scrape()        
    try:
        n_page=driver.find_elements(By.XPATH,"//nav[@class='yFHi8N']/a")
        np=[]
        for i in n_page:
            np.append(i.get_attribute('href'))
        for i in np[0:18]:
            driver.get(i)
            time.sleep(1)
            scrape()
    except: continue
print (f"Review Tiles Scraped:{len(title)}\nReveiws Scraped:{len(review_text)}\
\nRatings Scraped:{len(ratings)}")
# Out:
# The amount of URLs gathered is: 192
# Review Tiles Scraped:17548
# Reveiws Scraped:17548
# Ratings Scraped:17548

# %%
rat8=pd.DataFrame({'TITLE':title,'REVIEW':review_text,'RATINGS':ratings})

# %%
rat8
# Out:
#                    TITLE                                             REVIEW  \
# 0            Pretty good  The best for WFH and daily usage. Compact, rob...
# 1      Terrific purchase  It's great purchase. I trust lenovo. It's beau...
# 2          Great product  I think this is good for my requirement I got ...
# 3            Really Nice        It fullfill your every desire as you expect
# 4              Just wow!  Great product , best for remote use and travel...
# ...                  ...                                                ...
# 17543          Just wow!  Almost Good phone. Touch is good\nDisplay wow ...
# 17544          Very Good  Received the phone today. Thanks to Flipkart w...
# 17545    Worth the money  Phone's best part is its body finish,stereo sp...
# 17546    Useless product  I am a tech savvy guy . Used lots of phones . ...
# 17547        Pretty good  If you are searching for all rounder phone the...
#
#       RATINGS
# 0           4
# 1           5
# 2           5
# 3           4
# 4           5
# ...       ...
# 17543       5
# 17544       4
# 17545       4
# 17546       1
# 17547       4
#
# [17548 rows x 3 columns]

# %%
rat1.to_excel('RAT1.xlsx')

# %%
rat2.to_excel('RAT2.xlsx')

# %%
rat3.to_excel('RAT3.xlsx')

# %%
rat4.to_excel('RAT4.xlsx')

# %%
rat5.to_excel('RAT5.xlsx')

# %%
rat6.to_excel('RAT6.xlsx')

# %%
rat7.to_excel('RAT7.xlsx')

# %%
rat8.to_excel('RAT8.xlsx')
